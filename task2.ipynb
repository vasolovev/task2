# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

import streamlit as st

from streamlit_jupyter import StreamlitPatcher, tqdm

StreamlitPatcher().jupyter()


# https://www.kaggle.com/datasets/missionjee/students-dropout-and-academic-success-dataset

# %%
df = pd.read_csv('file.csv', sep=";")

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance\t', 'Previous qualification',
#        'Previous qualification (grade)', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Admission grade',
#        'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Scholarship holder',
#        'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
# ...

# %%
missing_values = df.isnull().sum()

# %%
categorical_vars = ['Marital status', 'Application mode', 'Daytime/evening attendance\t', 'Previous qualification', 'Nacionality', 'Mother\'s qualification', 'Father\'s qualification', 'Mother\'s occupation', 'Father\'s occupation', 'Gender', 'International']
numeric_vars = ['Age at enrollment', 'Admission grade', 'Unemployment rate', 'Inflation rate', 'GDP']

for var in categorical_vars:
    print(f'Уникальные значения для {var}: {df[var].unique()}')
# Out:
# Уникальные значения для Marital status: [1 2 4 3 5 6]
# Уникальные значения для Application mode: [17 15  1 39 18 53 44 51 43  7 42 16  5  2 10 57 26 27]
# Уникальные значения для Daytime/evening attendance	: [1 0]
# Уникальные значения для Previous qualification: [ 1 19 42 39 10  3 40  2  4 12 43 15  6  9 38  5 14]
# Уникальные значения для Nacionality: [  1  62   6  41  26 103  13  25  21 101  11  22  32 100  24 109   2 108
#  105  14  17]
# Уникальные значения для Mother's qualification: [19  1 37 38  3  4 42  2 34 12 40  9  5 39 11 41 30 14 35 36  6 10 29 43
#  18 22 27 26 44]
# Уникальные значения для Father's qualification: [12  3 37 38  1 19  5  4 34  2 39 11  9 36 26 40 14 20 35 41 22 13 29 43
#  18 42 10  6 30 25 44 33 27 31]
# Уникальные значения для Mother's occupation: [  5   3   9   7   4   1 125   0   6   2  90   8 141 175  99 191 151 194
#  192 132 152 134  10 143 123 173 193 122 144 131 171 153]
# ...

# %%
st.set_option('deprecation.showPyplotGlobalUse', False)
df[numeric_vars].hist(bins=20, figsize=(15, 10))
plt.show()

# %%
sns.boxplot(data=df, x="Target", y="Age at enrollment")
# Out:
# <Axes: xlabel='Target', ylabel='Age at enrollment'>

# %%
sns.boxplot(data=df[(df['Age at enrollment']<31)], x="Target", y="Age at enrollment")
# Out:
# <Axes: xlabel='Target', ylabel='Age at enrollment'>

# %%
sns.set_style("whitegrid")
sns.scatterplot(data=df, x="Previous qualification", y="GDP")
# Out:
# <Axes: xlabel='Previous qualification', ylabel='GDP'>

# %%
df[df['Age at enrollment'] > 25].__len__()
# Out:
# 1045

# %%
df[(df['Age at enrollment'] > 50) & (df["Target"]=="Graduate")]
# Out:
#       Marital status  Application mode  Application order  Course  \
# 707                2                39                  1    9003
# 725                4                 7                  1    9500
# 744                1                39                  1    9773
# 768                2                39                  1    8014
# 887                1                43                  2    9238
# 1532               2                15                  1    9773
# 1552               1                 7                  1    9147
# 1630               2                39                  1    9130
# 1632               2                39                  1    9991
# 2401               2                39                  1    9991
# 2447               2                39                  1    9254
# 2456               1                39                  1    9070
# 2661               2                39                  1    9773
# ...

# %%
df.groupby('Marital status')['Age at enrollment'].mean()
# Out:
# Marital status
# 1    21.525644
# 2    36.720317
# 3    33.000000
# 4    38.395604
# 5    30.880000
# 6    41.833333
# Name: Age at enrollment, dtype: float64

# %%
df[df['International'] == 1]

pivot = df.pivot_table(
    index=["Mother's qualification"],
    columns=["Previous qualification (grade)"],
    values="GDP",
    aggfunc=np.average)
sns.heatmap(pivot)
# Out:
# <Axes: xlabel='Previous qualification (grade)', ylabel="Mother's qualification">

# %%
df[df['Target'] == "Graduate"]
# Out:
#       Marital status  Application mode  Application order  Course  \
# 1                  1                15                  1    9254
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# 5                  2                39                  1    9991
# 6                  1                 1                  1    9500
# ...              ...               ...                ...     ...
# 4417               1                 1                  1    9070
# 4418               1                44                  1    9070
# 4419               1                 1                  6    9773
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 1                                1                       1
# ...

# %%
df.groupby('Previous qualification')['Admission grade'].max()
# Out:
# Previous qualification
# 1     190.0
# 2     155.7
# 3     184.0
# 4     190.0
# 5     140.0
# 6     145.0
# 9     128.2
# 10    128.8
# 12    160.0
# 14    100.0
# 15    101.0
# 19    170.0
# 38    154.0
# 39    180.0
# 40    190.0
# 42    170.0
# 43    180.0
# Name: Admission grade, dtype: float64

# %%
df.groupby(['Marital status'])

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(df['Curricular units 1st sem (grade)'], kde=True, bins=30, color="skyblue")
plt.title('Распределение оценок за первый семестр')
plt.xlabel('Оценка')
plt.ylabel('Количество студентов')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Marital status', y='Curricular units 1st sem (grade)', data=df, palette="magma")
plt.title('Средние оценки в зависимости от семейного положения')
plt.xlabel('Семейное положение')
plt.ylabel('Средняя оценка за первый семестр')
plt.show()
# Out:
# /tmp/ipykernel_21726/3181302788.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Marital status', y='Curricular units 1st sem (grade)', data=df, palette="magma")

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age at enrollment', y='Curricular units 1st sem (grade)', data=df, color="purple")
plt.title('Взаимосвязь между возрастом при поступлении и средней оценкой за первый семестр')
plt.xlabel('Возраст при поступлении')
plt.ylabel('Средняя оценка за первый семестр')
plt.show()
